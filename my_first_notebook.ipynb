# %%
Hardware refers to physical components of a computer. Keyboard, Monitor and CPU are the examples of Hardware.
Software is the set of programs that run on a computer and control the hardware. The example of software is "Windows".
